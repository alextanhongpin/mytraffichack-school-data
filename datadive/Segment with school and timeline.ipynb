# %%
import pandas

# %%
segments_with_school = pandas.read_csv("kl_segments.csv")

# %%
segments_with_school
# Out:
#                                               the_geom  cartodb_id  \
# 0    0103000020E61000000100000026000000C9004978AD5B...        6774
# 1    0103000020E610000001000000290000000867E6B4EF5B...        1891
# 2    0103000020E6100000010000004600000056AD0003C65B...        1735
# 3    0103000020E6100000010000004D00000085763289B45B...        1679
# 4    0103000020E61000000100000041000000AAC4B4FA1A5C...         258
# 5    0103000020E61000000100000047000000D4595BE0135C...        1703
# 6    0103000020E61000000100000027000000A59E0DAB135C...        1702
# 7    0103000020E61000000100000043000000D0AEC4DE155C...        1701
# 8    0103000020E610000001000000230000008809F116365C...        6747
# 9    0103000020E6100000010000003C0000007B874548355C...        1889
# 10   0103000020E6100000010000003F0000003199CD427E5C...         268
# 11   0103000020E610000001000000470000001E48DB5D435C...        6547
# 12   0103000020E61000000100000044000000748DF81B725C...        6693
# ...

# %%
mon_week_one = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_mon.csv", index_col="segment_id")

# %%
tue_week_one = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_tue.csv", index_col="segment_id")

# %%
wed_week_one = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_wed.csv", index_col="segment_id")

# %%
thur_week_one = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_thur.csv", index_col="segment_id")

# %%
fri_week_one = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_fri.csv", index_col="segment_id")

# %%
sat_week_one = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_sat.csv", index_col="segment_id")

# %%
mon_week_one
# Out:
#               day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# segment_id
# 36071284489        31        22.0         NaN         NaN        34.0
# 295681671904       68         NaN        62.0         NaN         NaN
# 172939812617       29        60.0         NaN         NaN         NaN
# 290178745056       47        52.0        42.0        55.0        48.0
# 30736129801        15         NaN         NaN         NaN         NaN
# 64525442825        34        40.0        36.0        40.0         NaN
# 319203328736       42         NaN         NaN         NaN         NaN
# 241223081737       39         NaN         NaN         NaN         NaN
# 196629241609       47         NaN         NaN         NaN         NaN
# 279508435680       47        66.0        48.0        55.0        51.0
# 139855142665       22        29.0        17.0         NaN         NaN
# 118514523913       54        57.0        59.0         NaN        59.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import random

# %%
segment_sample = [
    118111617760,
    249208783584,
    248604803808,
    276991853280,
    277025407712,
    255215026912,
    118413607648,
    95294604000,
]

# %%
for segment_id in segment_sample:
    mon_week_one.loc[segment_id].drop("day_avg").plot(title=str(segment_id))
    #plt.show()

# %%
for segment_id in segment_sample:
    sat_week_one.loc[segment_id].drop("day_avg").plot(title=str(segment_id))
    #plt.show()
