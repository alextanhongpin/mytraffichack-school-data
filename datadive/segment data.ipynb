# %%
import pandas

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df = pandas.read_csv("summarize_mon_school.csv")

# %%
df
# Out:
#      cartodb_id                                           the_geom  \
# 0            49  0105000020E61000000100000001020000000200000056...
# 1            50  0105000020E61000000100000001020000000600000000...
# 2            55  0105000020E610000001000000010200000002000000EE...
# 3            57  0105000020E61000000100000001020000000300000053...
# 4            81  0105000020E610000003000000010200000003000000D3...
# 5            84  0105000020E610000001000000010200000008000000BF...
# 6            91  0105000020E6100000020000000102000000020000008D...
# 7            96  0105000020E61000000100000001020000000300000000...
# 8            97  0105000020E61000000200000001020000000300000099...
# 9           102  0105000020E61000000100000001020000000200000073...
# 10          146  0105000020E610000001000000010200000002000000E8...
# 11          148  0105000020E61000000100000001020000000200000020...
# 12         2013  0105000020E610000002000000010200000002000000C0...
# ...

# %%
df["hour_5_avg"]
# Out:
# 0       NaN
# 1       NaN
# 2      44.0
# 3      39.0
# 4      50.0
# 5       NaN
# 6      40.0
# 7       NaN
# 8      68.0
# 9      37.0
# 10      NaN
# 11      NaN
# 12     84.0
# 13      NaN
# 14     46.0
# 15     79.0
# 16      NaN
# 17      NaN
# 18     68.0
# 19     54.0
# 20     55.0
# 21      NaN
# 22      NaN
# 23      NaN
# 24     54.0
# 25      NaN
# 26     54.0
# 27      NaN
# 28     82.0
# 29      NaN
#        ...
# 298    55.0
# 299    45.0
# 300     NaN
# 301    63.0
# 302     NaN
# 303    72.0
# 304    37.0
# 305     NaN
# 306     NaN
# 307     NaN
# 308    55.0
# 309    34.0
# 310     NaN
# 311     NaN
# 312     NaN
# 313     NaN
# 314    53.0
# 315     NaN
# 316     NaN
# 317     NaN
# 318     NaN
# 319     NaN
# 320    88.0
# 321     NaN
# 322     NaN
# 323     NaN
# 324    30.0
# 325     NaN
# 326    81.0
# 327     NaN
# Name: hour_5_avg, dtype: float64

# %%
ax = df["hour_5_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("monday_5.png")

# %%
ax = df["hour_21_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("monday_21.png")

# %%
ax=df["hour_7_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("monday_7.png")

# %%
sat_df = pandas.read_csv("summarize_sat_school.csv")

# %%
sat_df
# Out:
#      cartodb_id                                           the_geom  \
# 0            49  0105000020E61000000100000001020000000200000056...
# 1            50  0105000020E61000000100000001020000000600000000...
# 2            55  0105000020E610000001000000010200000002000000EE...
# 3            57  0105000020E61000000100000001020000000300000053...
# 4            63  0105000020E61000000200000001020000000400000027...
# 5            81  0105000020E610000003000000010200000003000000D3...
# 6            84  0105000020E610000001000000010200000008000000BF...
# 7            91  0105000020E6100000020000000102000000020000008D...
# 8            96  0105000020E61000000100000001020000000300000000...
# 9            97  0105000020E61000000200000001020000000300000099...
# 10          102  0105000020E61000000100000001020000000200000073...
# 11          148  0105000020E61000000100000001020000000200000020...
# 12         2013  0105000020E610000002000000010200000002000000C0...
# ...

# %%
ax = sat_df["hour_7_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("sat_7.png")

# %%
ax = sat_df["hour_21_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("sat_21.png")

# %%
ax = sat_df["hour_5_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("sat_5.png")

# %%
monl = pandas.read_csv("kl_traffic_data_hackathon/week_2016-01-11/summarized_mon.csv", index_col="segment_id")

# %%
mon_no_school["hour_7_avg"].hist()

# %%
df
# Out:
#      cartodb_id                                           the_geom  \
# 0            49  0105000020E61000000100000001020000000200000056...
# 1            50  0105000020E61000000100000001020000000600000000...
# 2            55  0105000020E610000001000000010200000002000000EE...
# 3            57  0105000020E61000000100000001020000000300000053...
# 4            81  0105000020E610000003000000010200000003000000D3...
# 5            84  0105000020E610000001000000010200000008000000BF...
# 6            91  0105000020E6100000020000000102000000020000008D...
# 7            96  0105000020E61000000100000001020000000300000000...
# 8            97  0105000020E61000000200000001020000000300000099...
# 9           102  0105000020E61000000100000001020000000200000073...
# 10          146  0105000020E610000001000000010200000002000000E8...
# 11          148  0105000020E61000000100000001020000000200000020...
# 12         2013  0105000020E610000002000000010200000002000000C0...
# ...

# %%
ax = mon["hour_7_avg"].hist(orientation="horizontal")
ax.set_xlabel("distribution")
ax.set_ylabel("Speed in km/H")
fig = ax.get_figure()
fig.savefig("mon_all_7.png")
